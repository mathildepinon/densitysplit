# %%
from os.path import exists
import sys
import numpy as np

from cosmoprimo import *
from pycorr import TwoPointCorrelationFunction, setup_logging
from mockfactory import EulerianLinearMock, LagrangianLinearMock, RandomBoxCatalog, setup_logging

from densitysplit import catalog_data, density_split
from bin.density_split_mocks_functions import generate_N_mocks, generate_batch_2PCF, generate_batch_densitySplit_CCF

# Set up logging
setup_logging()

# %%
def generate_densitySplit_CCF(catalog, nmocks, nmesh, bias,
                                    cellsize, resampler, nsplits, use_rsd,
                                    randoms_size, edges, los, f=None, rsd=False, use_weights=False, nbar=None,
                                    nthreads=128,
                                    batch_size=None, batch_index=0,
                                    save_each=False, output_dir='', mpi=False, overwrite=True):

    if nbar is None:
        nbar=catalog.size/catalog.boxsize**3

    results_hh_auto = list()
    results_hh_cross = list()
    results_rh = list()

    if batch_size is None:
        batch_size = nmocks

    mocks_indices = range(batch_index*batch_size, (batch_index+1)*batch_size)

    for i in mocks_indices:
        print('Mock '+str(i))
        filename = catalog.name+'_gaussianMock{}_truncatedPk'.format(i)
        if exists(output_dir+filename+'.npy') and not overwrite:
            print('Mock already exists. Loading mock...')
            mock_catalog = catalog_data.Data.load(output_dir+filename+'.npy')
        else:
            print('Mock does not exist. Generating mock...')
            mock_catalog = generate_mock(nmesh=nmesh, boxsize=catalog.boxsize, boxcenter=catalog.boxcenter, seed=i,
                                         cosmology=fiducial.AbacusSummitBase(), nbar=catalog.size/catalog.boxsize**3,
                                         z=catalog.redshift, bias=bias,
                                         rsd=rsd, los=los, f=f,
                                         save=save_each, output_dir=output_dir, name=filename,
                                         mpi=mpi)

        if mock_catalog is not None:
            print('Computing density splits...')
            mock_density = split_density(mock_catalog, cellsize, resampler, nsplits, use_rsd=use_rsd, use_weights=use_weights, save=False)
            print('Computing correlation function...')
            mock_CCFs = compute_densitySplit_CCF(mock_density, edges, los, use_rsd=rsd, use_weights=use_weights, randoms_size=randoms_size, nthreads=nthreads)
            result_hh_auto = mock_CCFs['hh_auto']
            result_hh_cross = mock_CCFs['hh_cross']
            result_rh = mock_CCFs['rh']

            results_hh_auto.append(result_hh_auto)
            results_hh_cross.append(result_hh_cross)
            results_rh.append(result_rh)

    return results_hh_auto, results_hh_cross, results_rh

# %%
def split_density(catalog, cellsize, resampler, nsplits, use_rsd=False, use_weights=False, save=False, output_dir=''):
    catalog_density = density_split.DensitySplit(catalog)
    catalog_density.compute_density(cellsize=cellsize, resampler=resampler, use_rsd=use_rsd, use_weights=use_weights)
    catalog_density.split_density(nsplits)

    if save:
        catalog_density.save(output_dir+catalog.name+'_density')

    return catalog_density


def compute_densitySplit_CCF(data_density_splits, edges, los, use_rsd=False, use_weights=False, save=False, output_dir='', name='mock', randoms_size=1, nthreads=128):
    data = data_density_splits.data

    if use_rsd and data.positions_rsd is not None:
        rsd_info = '_RSD'
        positions = data.positions_rsd
        split_positions = data_density_splits.split_positions_rsd
    else:
        rsd_info = ''
        positions = data.positions
        split_positions = data_density_splits.split_positions

    if use_weights and (data.weights is not None):
        weights = data.weights
        split_weights = [weights[data_density_splits.split_indices[split]] for split in range(data_density_splits.nsplits)]
    else:
        weights = None
        split_weights = [None for split in range(data_density_splits.nsplits)]

    split_samples = data_density_splits.sample_splits(size=randoms_size*data_density_splits.data.size, seed=0, update=False)
    cellsize = data_density_splits.cellsize

    results_hh_auto = list()
    results_hh_cross = list()
    results_rh = list()

    for i in range(data_density_splits.nsplits):
        result_hh_auto = TwoPointCorrelationFunction('smu', edges,
                                                data_positions1=split_positions[i], data_weights1=split_weights[i],
                                                boxsize=data_density_splits.boxsize,
                                                engine='corrfunc', nthreads=128,
                                                los = los)

        cross_indices = [j for j in range(data_density_splits.nsplits) if j!=i]
        cross_positions = np.concatenate([split_positions[j] for j in cross_indices], axis=1)
        if use_weights and (data.weights is not None):
            cross_weights = np.concatenate([split_weights[j] for j in cross_indices])
        else:
            cross_weights = None
        result_hh_cross = TwoPointCorrelationFunction('smu', edges,
                                                data_positions1=split_positions[i], data_positions2=cross_positions,
                                                data_weights1=split_weights[i], data_weights2=cross_weights,
                                                boxsize=data_density_splits.boxsize,
                                                engine='corrfunc', nthreads=nthreads,
                                                los = los)

        result_rh = TwoPointCorrelationFunction('smu', edges,
                                                data_positions1=split_samples[i], data_positions2=positions,
                                                data_weights1=None, data_weights2=weights,
                                                boxsize=data_density_splits.boxsize,
                                                engine='corrfunc', nthreads=nthreads,
                                                los = los)

        results_hh_auto.append(result_hh_auto)
        results_hh_cross.append(result_hh_cross)
        results_rh.append(result_rh)

    if save:
        np.save(output_dir+name+'_densitySplit_hh_autoCFs_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+rsd_info, results_hh_auto)
        np.save(output_dir+name+'_densitySplit_hh_crossCFs_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+rsd_info, results_hh_cross)
        np.save(output_dir+name+'_densitySplit_rh_CCFs_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+rsd_info, results_rh)

    return {'hh_auto': results_hh_auto, 'hh_cross': results_hh_cross, 'rh': results_rh}

# %%
# Mock batch
#batch_index = int(sys.argv[1])
#batch_index = 0

# Data and output directories
data_dir = '/feynman/work/dphp/mp270220/data/'
output_dir = '/feynman/work/dphp/mp270220/outputs/'


# Get data
catalog_name = 'AbacusSummit_1Gpc_z1.175'
bias = 1.8

#catalog_name = 'AbacusSummit_2Gpc_z1.175'
#bias = 3.

#catalog_name = 'AbacusSummit_2Gpc_z0.800'
#catalog_name = 'mock'

catalog = catalog_data.Data.load(data_dir+catalog_name+'.npy')
catalog.shift_boxcenter(-catalog.offset)

# Parameters

# Density mesh
cellsize = 10
resampler = 'tsc'
nsplits = 3

# Correlation function
randoms_size = 4
edges = (np.linspace(0., 150., 51), np.linspace(-1, 1, 201))
los = 'x'

# Mocks
nmocks = 4000
nmesh = 512
nbar = catalog.size/catalog.boxsize**3

# For RSD
cosmology=fiducial.AbacusSummitBase()
bg = cosmology.get_background()
f = bg.growth_rate(catalog.redshift)

# Set RSD
hz = 100*bg.efunc(catalog.redshift)
catalog.set_rsd(hz=hz)

results_hh_auto, results_hh_cross, results_rh = generate_densitySplit_CCF(catalog, nmocks=10,
                                                                                 nmesh=nmesh,
                                                                                 bias=bias,
                                                                                 cellsize=cellsize, resampler=resampler, nsplits=nsplits, use_rsd=False,
                                                                                 randoms_size=randoms_size,
                                                                                 edges=edges, los=los, f=f, rsd=False, use_weights=True, nbar=nbar,
                                                                                 nthreads=128, batch_size=None, batch_index=0,
                                                                                 save_each=True, output_dir=output_dir+'mocks_rsd/', mpi=False, overwrite=False)

# np.save(output_dir+catalog.name+'_10_gaussianMocks_2PCF', results)
# np.save(output_dir+catalog.name+'_4000_mocks_2PCF_batch'+str(batch_index), results)
# np.save(output_dir+catalog.name+'_4000_mocks_densitySplit_hh_autoCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+'_batch'+str(batch_index), results_hh_auto)
# np.save(output_dir+catalog.name+'_4000_mocks_densitySplit_hh_crossCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+'_batch'+str(batch_index), results_hh_cross)
# np.save(output_dir+catalog.name+'_4000_mocks_densitySplit_rh_CCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size)+'_batch'+str(batch_index), results_rh)
np.save(output_dir+catalog.name+'_10_gaussianMocks_truncatedPk_densitySplit_hh_autoCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size), results_hh_auto)
np.save(output_dir+catalog.name+'_10_gaussianMocks_truncatedPk_densitySplit_hh_crossCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size), results_hh_cross)
np.save(output_dir+catalog.name+'_10_gaussianMocks_truncatedPk_densitySplit_rh_CCF_cellsize'+str(cellsize)+'_randomsize'+str(randoms_size), results_rh)
# Out:
# Mock 0
# Mock already exists. Loading mock...
# Computing density splits...
# [000000.88] [0/1] 06-14 10:24  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [000001.66] [0/1] 06-14 10:24  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [000003.80] [0/1] 06-14 10:24  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000003.80] [0/1] 06-14 10:24  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000008.77] [0/1] 06-14 10:24  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000008.77] [0/1] 06-14 10:24  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000008.77] [0/1] 06-14 10:24  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000024.31] [0/1] 06-14 10:25  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000024.31] [0/1] 06-14 10:25  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000024.32] [0/1] 06-14 10:25  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000124.32] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000124.32] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000124.32] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000129.40] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000129.41] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000129.41] [0/1] 06-14 10:26  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000145.25] [0/1] 06-14 10:27  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000145.26] [0/1] 06-14 10:27  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000145.26] [0/1] 06-14 10:27  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000245.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000245.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000245.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000250.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000250.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000250.97] [0/1] 06-14 10:28  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000266.72] [0/1] 06-14 10:29  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000266.73] [0/1] 06-14 10:29  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000266.73] [0/1] 06-14 10:29  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000348.53] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 1
# Mock already exists. Loading mock...
# Computing density splits...
# [000349.23] [0/1] 06-14 10:30  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [000350.03] [0/1] 06-14 10:30  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [000352.14] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000352.14] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000357.13] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000357.14] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000357.14] [0/1] 06-14 10:30  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000372.78] [0/1] 06-14 10:31  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000372.79] [0/1] 06-14 10:31  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000372.79] [0/1] 06-14 10:31  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000472.66] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000472.66] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000472.66] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000477.71] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000477.72] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000477.72] [0/1] 06-14 10:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000493.51] [0/1] 06-14 10:33  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000493.51] [0/1] 06-14 10:33  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000493.51] [0/1] 06-14 10:33  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000593.98] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000593.98] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000593.98] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000598.95] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000598.96] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000598.96] [0/1] 06-14 10:34  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000614.65] [0/1] 06-14 10:35  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000614.65] [0/1] 06-14 10:35  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000614.65] [0/1] 06-14 10:35  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000696.13] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 2
# Mock already exists. Loading mock...
# Computing density splits...
# [000696.86] [0/1] 06-14 10:36  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [000697.64] [0/1] 06-14 10:36  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [000699.73] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000699.73] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000704.69] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000704.69] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000704.69] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000720.33] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000720.33] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000720.33] [0/1] 06-14 10:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000820.37] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000820.37] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000820.37] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000825.43] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000825.44] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000825.44] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000841.24] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000841.24] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000841.24] [0/1] 06-14 10:38  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000941.60] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000941.60] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000941.60] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000946.54] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000946.55] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000946.55] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000962.27] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [000962.27] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [000962.27] [0/1] 06-14 10:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001043.92] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 3
# Mock already exists. Loading mock...
# Computing density splits...
# [001044.65] [0/1] 06-14 10:42  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [001045.43] [0/1] 06-14 10:42  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [001047.56] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001047.56] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001052.51] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001052.52] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001052.52] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001068.19] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001068.19] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001068.19] [0/1] 06-14 10:42  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001168.24] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001168.24] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001168.24] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001173.29] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001173.30] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001173.30] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001189.11] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001189.11] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001189.11] [0/1] 06-14 10:44  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001289.55] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001289.55] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001289.55] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001294.49] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001294.50] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001294.50] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001310.20] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001310.20] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001310.20] [0/1] 06-14 10:46  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001391.80] [0/1] 06-14 10:47  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 4
# Mock already exists. Loading mock...
# Computing density splits...
# [001392.53] [0/1] 06-14 10:48  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [001393.32] [0/1] 06-14 10:48  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [001395.45] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001395.45] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001400.40] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001400.41] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001400.41] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001416.06] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001416.06] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001416.06] [0/1] 06-14 10:48  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001516.27] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001516.27] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001516.27] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001521.32] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001521.32] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001521.32] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001537.13] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001537.13] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001537.13] [0/1] 06-14 10:50  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001637.63] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001637.63] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001637.63] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001642.58] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001642.59] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001642.59] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001658.27] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001658.27] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001658.27] [0/1] 06-14 10:52  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001739.89] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 5
# Mock already exists. Loading mock...
# Computing density splits...
# [001740.61] [0/1] 06-14 10:53  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [001741.40] [0/1] 06-14 10:53  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [001743.51] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001743.51] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001748.47] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001748.48] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001748.48] [0/1] 06-14 10:53  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001764.15] [0/1] 06-14 10:54  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001764.15] [0/1] 06-14 10:54  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001764.15] [0/1] 06-14 10:54  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001864.18] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001864.18] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001864.19] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001869.23] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001869.24] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001869.24] [0/1] 06-14 10:55  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001885.07] [0/1] 06-14 10:56  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001885.07] [0/1] 06-14 10:56  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001885.07] [0/1] 06-14 10:56  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001985.56] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001985.56] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001985.56] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001990.50] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [001990.51] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [001990.51] [0/1] 06-14 10:57  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002006.23] [0/1] 06-14 10:58  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002006.24] [0/1] 06-14 10:58  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002006.24] [0/1] 06-14 10:58  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002087.98] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 6
# Mock already exists. Loading mock...
# Computing density splits...
# [002088.72] [0/1] 06-14 10:59  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [002089.50] [0/1] 06-14 10:59  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [002091.60] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002091.60] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002096.56] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002096.57] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002096.57] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002112.25] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002112.25] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002112.25] [0/1] 06-14 10:59  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002212.55] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002212.55] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002212.55] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002217.60] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002217.61] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002217.61] [0/1] 06-14 11:01  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002233.42] [0/1] 06-14 11:02  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002233.42] [0/1] 06-14 11:02  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002233.42] [0/1] 06-14 11:02  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002333.71] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002333.71] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002333.72] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002338.65] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002338.66] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002338.66] [0/1] 06-14 11:03  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002354.39] [0/1] 06-14 11:04  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002354.40] [0/1] 06-14 11:04  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002354.40] [0/1] 06-14 11:04  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002435.94] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 7
# Mock already exists. Loading mock...
# Computing density splits...
# [002436.67] [0/1] 06-14 11:05  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [002437.47] [0/1] 06-14 11:05  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [002439.63] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002439.63] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002444.59] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002444.60] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002444.60] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002460.25] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002460.26] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002460.26] [0/1] 06-14 11:05  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002560.50] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002560.50] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002560.50] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002565.55] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002565.56] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002565.56] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002581.38] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002581.38] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002581.38] [0/1] 06-14 11:07  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002681.81] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002681.82] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002681.82] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002686.75] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002686.76] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002686.76] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002702.48] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002702.48] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002702.48] [0/1] 06-14 11:09  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002784.04] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 8
# Mock already exists. Loading mock...
# Computing density splits...
# [002784.76] [0/1] 06-14 11:11  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [002785.54] [0/1] 06-14 11:11  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [002787.64] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002787.64] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002792.60] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002792.60] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002792.60] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002808.25] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002808.25] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002808.25] [0/1] 06-14 11:11  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002908.25] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002908.26] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002908.26] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002913.30] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002913.31] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002913.31] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [002929.12] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [002929.12] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [002929.12] [0/1] 06-14 11:13  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003029.67] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003029.67] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003029.67] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003034.61] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003034.62] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003034.62] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003050.33] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003050.33] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003050.33] [0/1] 06-14 11:15  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003131.91] [0/1] 06-14 11:16  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# Mock 9
# Mock already exists. Loading mock...
# Computing density splits...
# [003132.64] [0/1] 06-14 11:17  CatalogMesh               INFO     Slab 0 ~ 4194304 / 2934922.
# [003133.44] [0/1] 06-14 11:17  CatalogMesh               INFO     Painted 2934922 out of 2934922 objects to mesh.
# Computing correlation function...
# [003135.57] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003135.57] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003140.53] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003140.54] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003140.54] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003156.22] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003156.22] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003156.22] [0/1] 06-14 11:17  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003256.47] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003256.47] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003256.47] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003261.53] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003261.53] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003261.53] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003277.35] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003277.35] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003277.35] [0/1] 06-14 11:19  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003377.73] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003377.73] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003377.73] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003382.68] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003382.69] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003382.69] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003398.40] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.
# [003398.40] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_estimator.NaturalTwoPointEstimator'>.
# [003398.40] [0/1] 06-14 11:21  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [003479.80] [0/1] 06-14 11:22  TwoPointCorrelationFunction INFO     Analytically computing two-point counts R1R2.

# %%
results_rh
# Out:
# [[<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecf3caa00>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775d90>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb8ef760>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775c40>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f40d0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb8efb80>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb8ef520>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f48b0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775100>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecfa0f100>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775580>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb7de7f0>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb7de0a0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecfa0f580>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb8ef730>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f4d60>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f4b80>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb89bb20>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f4f40>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb7755e0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb7de3d0>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb887490>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775f10>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb89beb0>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffece9f4df0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb7de160>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb887940>],
#  [<pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb8959a0>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecb775640>,
#   <pycorr.twopoint_estimator.NaturalTwoPointEstimator at 0x7ffecf3caca0>]]
